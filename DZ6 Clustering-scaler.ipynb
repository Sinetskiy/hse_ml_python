# %% [markdown]
# ## Задание на кластеризацию. Срок: 5 декабря.

# %%
import numpy as np
import pandas as pd
import random
import math
import sklearn.datasets as ds 
import sklearn.metrics as metrics
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler

# %matplotlib inline

# %%
# Загрузите данные по покимонам

X = pd.read_csv("data/Pokemon.csv", index_col=0)
X.shape
# Out:
# (800, 12)

# %%
y = list(X['Legendary'].map({True: 1, False:0}))
X = X._get_numeric_data().dropna(axis=1).drop('Legendary', axis=1)

# %%
# Спойлер: попробуйте решить задачу со скейлингом и без

ms = MinMaxScaler()
ms.fit(X)
X = ms.transform(X)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:323: DataConversionWarning: Data with input dtype int64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
# С помощью TSNE отобразим данные на плоскости 
from sklearn.manifold import TSNE
tsne = TSNE(random_state=17, verbose=2, n_iter=10000, n_iter_without_progress=1000)

res = tsne.fit_transform(X)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 800 samples in 0.002s...
# [t-SNE] Computed neighbors for 800 samples in 0.336s...
# [t-SNE] Computed conditional probabilities for sample 800 / 800
# [t-SNE] Mean sigma: 0.149002
# [t-SNE] Computed conditional probabilities in 0.030s
# [t-SNE] Iteration 50: error = 64.7367249, gradient norm = 0.3759606 (50 iterations in 0.681s)
# [t-SNE] Iteration 100: error = 64.4262543, gradient norm = 0.3652945 (50 iterations in 0.574s)
# [t-SNE] Iteration 150: error = 63.9621849, gradient norm = 0.3675893 (50 iterations in 0.487s)
# [t-SNE] Iteration 200: error = 64.6097107, gradient norm = 0.3703400 (50 iterations in 0.454s)
# [t-SNE] Iteration 250: error = 64.6265717, gradient norm = 0.3703052 (50 iterations in 0.371s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 64.626572
# [t-SNE] Iteration 300: error = 0.8995736, gradient norm = 0.0013812 (50 iterations in 0.288s)
# [t-SNE] Iteration 350: error = 0.8384154, gradient norm = 0.0002755 (50 iterations in 0.263s)
# [t-SNE] Iteration 400: error = 0.8250228, gradient norm = 0.0001536 (50 iterations in 0.251s)
# [t-SNE] Iteration 450: error = 0.8207842, gradient norm = 0.0001158 (50 iterations in 0.320s)
# [t-SNE] Iteration 500: error = 0.8181157, gradient norm = 0.0001022 (50 iterations in 0.249s)
# [t-SNE] Iteration 550: error = 0.8171229, gradient norm = 0.0000940 (50 iterations in 0.275s)
# [t-SNE] Iteration 600: error = 0.8164052, gradient norm = 0.0000772 (50 iterations in 0.274s)
# [t-SNE] Iteration 650: error = 0.8159074, gradient norm = 0.0000744 (50 iterations in 0.244s)
# [t-SNE] Iteration 700: error = 0.8155467, gradient norm = 0.0000566 (50 iterations in 0.276s)
# [t-SNE] Iteration 750: error = 0.8152620, gradient norm = 0.0000591 (50 iterations in 0.261s)
# [t-SNE] Iteration 800: error = 0.8149151, gradient norm = 0.0000774 (50 iterations in 0.255s)
# [t-SNE] Iteration 850: error = 0.8148125, gradient norm = 0.0000541 (50 iterations in 0.278s)
# [t-SNE] Iteration 900: error = 0.8146568, gradient norm = 0.0000481 (50 iterations in 0.279s)
# [t-SNE] Iteration 950: error = 0.8144057, gradient norm = 0.0000629 (50 iterations in 0.277s)
# [t-SNE] Iteration 1000: error = 0.8142934, gradient norm = 0.0000392 (50 iterations in 0.286s)
# [t-SNE] Iteration 1050: error = 0.8142226, gradient norm = 0.0000485 (50 iterations in 0.267s)
# [t-SNE] Iteration 1100: error = 0.8141613, gradient norm = 0.0000440 (50 iterations in 0.272s)
# [t-SNE] Iteration 1150: error = 0.8141207, gradient norm = 0.0000416 (50 iterations in 0.291s)
# [t-SNE] Iteration 1200: error = 0.8140322, gradient norm = 0.0000373 (50 iterations in 0.295s)
# [t-SNE] Iteration 1250: error = 0.8139576, gradient norm = 0.0000418 (50 iterations in 0.250s)
# [t-SNE] Iteration 1300: error = 0.8138528, gradient norm = 0.0000291 (50 iterations in 0.287s)
# [t-SNE] Iteration 1350: error = 0.8132946, gradient norm = 0.0000399 (50 iterations in 0.250s)
# [t-SNE] Iteration 1400: error = 0.8132057, gradient norm = 0.0000554 (50 iterations in 0.289s)
# [t-SNE] Iteration 1450: error = 0.8131764, gradient norm = 0.0000430 (50 iterations in 0.265s)
# [t-SNE] Iteration 1500: error = 0.8131529, gradient norm = 0.0000774 (50 iterations in 0.288s)
# [t-SNE] Iteration 1550: error = 0.8130981, gradient norm = 0.0000402 (50 iterations in 0.295s)
# [t-SNE] Iteration 1600: error = 0.8131317, gradient norm = 0.0000456 (50 iterations in 0.257s)
# [t-SNE] Iteration 1650: error = 0.8129937, gradient norm = 0.0000409 (50 iterations in 0.302s)
# [t-SNE] Iteration 1700: error = 0.8129547, gradient norm = 0.0000583 (50 iterations in 0.282s)
# [t-SNE] Iteration 1750: error = 0.8128649, gradient norm = 0.0000464 (50 iterations in 0.259s)
# [t-SNE] Iteration 1800: error = 0.8128445, gradient norm = 0.0000601 (50 iterations in 0.290s)
# [t-SNE] Iteration 1850: error = 0.8127877, gradient norm = 0.0000492 (50 iterations in 0.295s)
# [t-SNE] Iteration 1900: error = 0.8126153, gradient norm = 0.0000558 (50 iterations in 0.285s)
# [t-SNE] Iteration 1950: error = 0.8125957, gradient norm = 0.0000449 (50 iterations in 0.297s)
# [t-SNE] Iteration 2000: error = 0.8126342, gradient norm = 0.0000508 (50 iterations in 0.254s)
# [t-SNE] Iteration 2050: error = 0.8126246, gradient norm = 0.0000425 (50 iterations in 0.290s)
# [t-SNE] Iteration 2100: error = 0.8125272, gradient norm = 0.0000658 (50 iterations in 0.263s)
# [t-SNE] Iteration 2150: error = 0.8125846, gradient norm = 0.0000441 (50 iterations in 0.313s)
# [t-SNE] Iteration 2200: error = 0.8125237, gradient norm = 0.0000516 (50 iterations in 0.349s)
# [t-SNE] Iteration 2250: error = 0.8125068, gradient norm = 0.0000533 (50 iterations in 0.280s)
# [t-SNE] Iteration 2300: error = 0.8124274, gradient norm = 0.0000434 (50 iterations in 0.353s)
# [t-SNE] Iteration 2350: error = 0.8125272, gradient norm = 0.0000483 (50 iterations in 0.347s)
# [t-SNE] Iteration 2400: error = 0.8124872, gradient norm = 0.0000534 (50 iterations in 0.484s)
# [t-SNE] Iteration 2450: error = 0.8124952, gradient norm = 0.0000462 (50 iterations in 0.390s)
# [t-SNE] Iteration 2500: error = 0.8124123, gradient norm = 0.0000595 (50 iterations in 0.304s)
# [t-SNE] Iteration 2550: error = 0.8125120, gradient norm = 0.0000640 (50 iterations in 0.348s)
# [t-SNE] Iteration 2600: error = 0.8124764, gradient norm = 0.0000615 (50 iterations in 0.267s)
# [t-SNE] Iteration 2650: error = 0.8124896, gradient norm = 0.0000438 (50 iterations in 0.254s)
# [t-SNE] Iteration 2700: error = 0.8124502, gradient norm = 0.0000502 (50 iterations in 0.338s)
# [t-SNE] Iteration 2750: error = 0.8124992, gradient norm = 0.0000444 (50 iterations in 0.267s)
# [t-SNE] Iteration 2800: error = 0.8124887, gradient norm = 0.0000330 (50 iterations in 0.334s)
# [t-SNE] Iteration 2850: error = 0.8124620, gradient norm = 0.0000282 (50 iterations in 0.264s)
# [t-SNE] Iteration 2900: error = 0.8124561, gradient norm = 0.0000721 (50 iterations in 0.246s)
# [t-SNE] Iteration 2950: error = 0.8124831, gradient norm = 0.0000510 (50 iterations in 0.274s)
# [t-SNE] Iteration 3000: error = 0.8123791, gradient norm = 0.0000637 (50 iterations in 0.248s)
# [t-SNE] Iteration 3050: error = 0.8124598, gradient norm = 0.0000471 (50 iterations in 0.261s)
# [t-SNE] Iteration 3100: error = 0.8124034, gradient norm = 0.0000465 (50 iterations in 0.277s)
# [t-SNE] Iteration 3150: error = 0.8124248, gradient norm = 0.0000657 (50 iterations in 0.244s)
# [t-SNE] Iteration 3200: error = 0.8124685, gradient norm = 0.0000491 (50 iterations in 0.280s)
# [t-SNE] Iteration 3250: error = 0.8123180, gradient norm = 0.0000362 (50 iterations in 0.244s)
# [t-SNE] Iteration 3300: error = 0.8123793, gradient norm = 0.0000747 (50 iterations in 0.266s)
# [t-SNE] Iteration 3350: error = 0.8123283, gradient norm = 0.0000715 (50 iterations in 0.286s)
# [t-SNE] Iteration 3400: error = 0.8123047, gradient norm = 0.0000489 (50 iterations in 0.244s)
# [t-SNE] Iteration 3450: error = 0.8122836, gradient norm = 0.0000420 (50 iterations in 0.262s)
# [t-SNE] Iteration 3500: error = 0.8123653, gradient norm = 0.0000626 (50 iterations in 0.277s)
# [t-SNE] Iteration 3550: error = 0.8122883, gradient norm = 0.0000630 (50 iterations in 0.244s)
# [t-SNE] Iteration 3600: error = 0.8122976, gradient norm = 0.0000548 (50 iterations in 0.282s)
# [t-SNE] Iteration 3650: error = 0.8123032, gradient norm = 0.0000570 (50 iterations in 0.265s)
# [t-SNE] Iteration 3700: error = 0.8123333, gradient norm = 0.0000466 (50 iterations in 0.247s)
# [t-SNE] Iteration 3750: error = 0.8123716, gradient norm = 0.0000446 (50 iterations in 0.271s)
# [t-SNE] Iteration 3800: error = 0.8124204, gradient norm = 0.0000412 (50 iterations in 0.243s)
# [t-SNE] Iteration 3850: error = 0.8123805, gradient norm = 0.0000438 (50 iterations in 0.257s)
# [t-SNE] Iteration 3900: error = 0.8123494, gradient norm = 0.0000441 (50 iterations in 0.331s)
# [t-SNE] Iteration 3950: error = 0.8123338, gradient norm = 0.0000655 (50 iterations in 0.265s)
# [t-SNE] Iteration 4000: error = 0.8123995, gradient norm = 0.0000436 (50 iterations in 0.313s)
# [t-SNE] Iteration 4050: error = 0.8123511, gradient norm = 0.0000556 (50 iterations in 0.272s)
# [t-SNE] Iteration 4100: error = 0.8123321, gradient norm = 0.0000343 (50 iterations in 0.247s)
# [t-SNE] Iteration 4150: error = 0.8123823, gradient norm = 0.0000420 (50 iterations in 0.267s)
# [t-SNE] Iteration 4200: error = 0.8123529, gradient norm = 0.0000425 (50 iterations in 0.278s)
# [t-SNE] Iteration 4250: error = 0.8123975, gradient norm = 0.0000356 (50 iterations in 0.252s)
# [t-SNE] Iteration 4300: error = 0.8124084, gradient norm = 0.0000380 (50 iterations in 0.274s)
# [t-SNE] Iteration 4350: error = 0.8124229, gradient norm = 0.0000413 (50 iterations in 0.244s)
# [t-SNE] Iteration 4400: error = 0.8123426, gradient norm = 0.0000398 (50 iterations in 0.333s)
# [t-SNE] Iteration 4450: error = 0.8123810, gradient norm = 0.0000525 (50 iterations in 0.311s)
# [t-SNE] Iteration 4500: error = 0.8124155, gradient norm = 0.0000387 (50 iterations in 0.263s)
# [t-SNE] Iteration 4500: did not make any progress during the last 1000 episodes. Finished.
# [t-SNE] KL divergence after 4500 iterations: 0.812415

# %%
# Посмотрим на реальное расположение классов

plt.figure(figsize=(12,8))
plt.scatter(res[:,0], res[:,1], c=y, s=10)
plt.title('TSNE')
# Out:
# Text(0.5, 1.0, 'TSNE')

# %% [markdown]
# Видно, что классы сгруппировались в одном месте. Но там не только они. Интересно, наши алгоритмы смогут что-то сделать?
#
# ### Kmeans

# %%
Ks = range(1, 15)
score = [KMeans(n_clusters=i, n_jobs=-1).fit(X).inertia_ for i in Ks]

# %%
plt.plot(Ks, score)

# %%
# Можно попробовать 3 или 4 кластера

kmeans = KMeans(n_clusters=4, random_state=1)
kmeans.fit(X)

plt.figure(figsize=(12,8))
plt.scatter(res[:,0], res[:,1], c=kmeans.labels_, s=10, cmap='viridis')
plt.title('TSNE')
# Out:
# Text(0.5, 1.0, 'TSNE')

# %% [markdown]
# Как и казалось очевидным, kmean побил на 3 видимых класса. И да, он поместил все семплы с таргетом 1 в один класс. На самом деле, это может быть полезным.
#
# #### Метрики
#
# Помимо метрики Silhouette, которую мы рассматривали на семинаре, есть метрики, которые считают качество кластеризации на данных, где есть разметка. Вместо данных они на вход получают кластеры и реальную разметку.
#
# Ниже перечислены некоторые из этих метрик. Как думаете, какая самая уместная в нашей задаче?

# %% [markdown]
# from sklearn import metrics
#
#         'AMI': metrics.adjusted_mutual_info_score(y, preds),
#         'ARI': metrics.adjusted_rand_score(y, preds),
#         'V-measure': metrics.v_measure_score(y, preds),
#         'Homogenity': metrics.homogeneity_score(y, preds),
#         'Completeness': metrics.completeness_score(y, preds)

# %% [markdown]
# ### DBSCAN
#
# Посмотрим, как DBSCAN справится с задачей кластеризации. Переберем разные значения параметров алгоритма и сравним качество по метрикам.
#
# Максимизация какой метрики, на ваш взгляд, дает лучшее разбиение?

# %%
from sklearn.cluster import DBSCAN
import numpy as np

# %%
#adjusted_mutual_info_score

eps = np.arange(0.3, 1, 0.1) #np.linspace(30, 130, 101)
# Если будете скалировать, то вам нужно будет взять eps < 1. Почему?
samples = range(3, 10)

scores = []
best_sc = -1
best_ep = None
best_sa = None
for ep in eps:
    for sa in samples:
        clst = DBSCAN(eps=ep, min_samples=sa)
        pred = clst.fit_predict(X)
        try:
            sc = metrics.adjusted_mutual_info_score(y, pred, average_method='geometric')
            if sc > best_sc:
                best_sc = sc
                best_ep = ep
                best_sa = sa
            scores.append((ep, sa, sc))
        except Exception as e:
            print(e)
            pass
     
clst = DBSCAN(eps=best_ep, min_samples=best_sa)
pred = clst.fit_predict(X)
print(metrics.adjusted_mutual_info_score(y, pred, average_method='geometric'))

plt.figure(figsize=(12,8))
plt.scatter(res[:,0], res[:,1], c=pred, s=10, cmap='viridis')
plt.title('TSNE - AMI')
# Out:
# 0.09517692309028979
# Text(0.5, 1.0, 'TSNE - AMI')

# %%
#adjusted_rand_score

eps = np.arange(0.3, 1, 0.1) #np.linspace(30, 130, 101)
# Если будете скалировать, то вам нужно будет взять eps < 1. Почему?
samples = range(3, 10)

scores = []
best_sc = -1
best_ep = None
best_sa = None
for ep in eps:
    for sa in samples:
        clst = DBSCAN(eps=ep, min_samples=sa)
        pred = clst.fit_predict(X)
        try:
            sc = metrics.adjusted_rand_score(y, pred)
            if sc > best_sc:
                best_sc = sc
                best_ep = ep
                best_sa = sa
            scores.append((ep, sa, sc))
        except:
            pass

clst = DBSCAN(eps=best_ep, min_samples=best_sa)
pred = clst.fit_predict(X)
print(metrics.adjusted_rand_score(y, pred))

plt.figure(figsize=(12,8))
plt.scatter(res[:,0], res[:,1], c=pred, s=10, cmap='viridis')
plt.title('TSNE - ARI')
# Out:
# 0.24679300343749355
# Text(0.5, 1.0, 'TSNE - ARI')

# %% [markdown]
# Повторите такую процедуру с остальными метриками и выберите, максимизация какой метрики, дает лучшее разбиение.
#
# #### Еще кластеризация
# Посмотрите на короткую справку по [типовым методам кластеризации](https://scikit-learn.org/stable/modules/clustering.html).
#
# Реализуйте еще какой-нибудь алгоритм, который вам нравится, и проведите то же исследование, что было с DBSCAN.
#
# Какой алгоритм и максимизация какой метрики дали наилучший визуальный результат? Почему?

# %%
#v_measure_score

eps = np.arange(0.3, 1, 0.1) #np.linspace(30, 130, 101)
# Если будете скалировать, то вам нужно будет взять eps < 1. Почему?
samples = range(3, 10)

scores = []
best_sc = -1
best_ep = None
best_sa = None
for ep in eps:
    for sa in samples:
        clst = DBSCAN(eps=ep, min_samples=sa)
        pred = clst.fit_predict(X)
        try:
            sc = metrics.v_measure_score(y, pred)
            if sc > best_sc:
                best_sc = sc
                best_ep = ep
                best_sa = sa
            scores.append((ep, sa, sc))
        except:
            pass

clst = DBSCAN(eps=best_ep, min_samples=best_sa)
pred = clst.fit_predict(X)
print(metrics.adjusted_rand_score(y, pred))

plt.figure(figsize=(12,8))
plt.scatter(res[:,0], res[:,1], c=pred, s=10, cmap='viridis')
plt.title('TSNE - V-measure')
# Out:
# 0.24679300343749355
# Text(0.5, 1.0, 'TSNE - V-measure')

# %%
#Homogenity

eps = np.arange(0.3, 1, 0.1) #np.linspace(30, 130, 101)
# Если будете скалировать, то вам нужно будет взять eps < 1. Почему?
samples = range(3, 10)

scores = []
best_sc = -1
best_ep = None
best_sa = None
for ep in eps:
    for sa in samples:
        clst = DBSCAN(eps=ep, min_samples=sa)
        pred = clst.fit_predict(X)
        try:
            sc = metrics.homogeneity_score(y, pred)
            if sc > best_sc:
                best_sc = sc
                best_ep = ep
                best_sa = sa
            scores.append((ep, sa, sc))
        except:
            pass

clst = DBSCAN(eps=best_ep, min_samples=best_sa)
pred = clst.fit_predict(X)
print(metrics.adjusted_rand_score(y, pred))

plt.figure(figsize=(12,8))
plt.scatter(res[:,0], res[:,1], c=pred, s=10, cmap='viridis')
plt.title('TSNE - Homogenity')
# Out:
# 0.24679300343749355
# Text(0.5, 1.0, 'TSNE - Homogenity')

# %%
#Completeness

eps = np.arange(0.3, 1, 0.1) #np.linspace(30, 130, 101)
# Если будете скалировать, то вам нужно будет взять eps < 1. Почему?
samples = range(3, 10)

scores = []
best_sc = -1
best_ep = None
best_sa = None
for ep in eps:
    for sa in samples:
        clst = DBSCAN(eps=ep, min_samples=sa)
        pred = clst.fit_predict(X)
        try:
            sc = metrics.completeness_score(y, pred)
            if sc > best_sc:
                best_sc = sc
                best_ep = ep
                best_sa = sa
            scores.append((ep, sa, sc))
        except:
            pass

clst = DBSCAN(eps=best_ep, min_samples=best_sa)
pred = clst.fit_predict(X)
print(metrics.adjusted_rand_score(y, pred))

plt.figure(figsize=(12,8))
plt.scatter(res[:,0], res[:,1], c=pred, s=10, cmap='viridis')
plt.title('TSNE - Completeness')
# Out:
# 0.0
# Text(0.5, 1.0, 'TSNE - Completeness')

# %% [markdown]
# # MeanShift
# Реализуйте еще какой-нибудь алгоритм, который вам нравится,
# и проведите то же исследование, что было с DBSCAN.

# %%
from sklearn.cluster import MeanShift, estimate_bandwidth

# The following bandwidth can be automatically detected using
_bandwidth = estimate_bandwidth(X, quantile=0.2, n_samples=500)
_bandwidth
# Out:
# 0.4952027345910742

# %%
best_bandwidth = _bandwidth
bandwidth_list = np.arange(best_bandwidth-0.4, best_bandwidth+0.5, 0.1)

clst = MeanShift(bandwidth=best_bandwidth, bin_seeding=True)
pred = clst.fit_predict(X)    
best_sc = metrics.adjusted_mutual_info_score(y, pred, average_method='geometric')

for bandwidth in bandwidth_list:
    clst = MeanShift(bandwidth=bandwidth, bin_seeding=True)
    pred = clst.fit_predict(X)
    try:
        sc = metrics.adjusted_mutual_info_score(y, pred, average_method='geometric')
        if sc > best_sc:
            best_bandwidth = bandwidth
    except:
        pass
    
clst = MeanShift(bandwidth=best_bandwidth, bin_seeding=True)
pred = clst.fit_predict(X)    
print(metrics.adjusted_mutual_info_score(y, pred, average_method='geometric'))

plt.figure(figsize=(12,8))
plt.scatter(res[:,0], res[:,1], c=pred, s=10, cmap='viridis')
plt.title('TSNE - MeanShift - AMI')
# Out:
# 0.0
# Text(0.5, 1.0, 'TSNE - MeanShift - AMI')

# %%
best_bandwidth = _bandwidth
bandwidth_list = np.arange(best_bandwidth-0.4, best_bandwidth+0.5, 0.1)

clst = MeanShift(bandwidth=best_bandwidth, bin_seeding=True)
pred = clst.fit_predict(X)    
best_sc = metrics.adjusted_rand_score(y, pred)

for bandwidth in bandwidth_list:
    clst = MeanShift(bandwidth=bandwidth, bin_seeding=True)
    pred = clst.fit_predict(X)
    try:
        sc = metrics.adjusted_rand_score(y, pred)
        if sc > best_sc:
            best_bandwidth = bandwidth
    except:
        pass
    
clst = MeanShift(bandwidth=best_bandwidth, bin_seeding=True)
pred = clst.fit_predict(X)
print(metrics.adjusted_rand_score(y, pred))

plt.figure(figsize=(12,8))
plt.scatter(res[:,0], res[:,1], c=pred, s=10, cmap='viridis')
plt.title('TSNE - MeanShift - ARI')
# Out:
# 0.0
# Text(0.5, 1.0, 'TSNE - MeanShift - ARI')

# %%
best_bandwidth = _bandwidth
bandwidth_list = np.arange(best_bandwidth-0.4, best_bandwidth+0.5, 0.1)

clst = MeanShift(bandwidth=best_bandwidth, bin_seeding=True)
pred = clst.fit_predict(X)    
best_sc = metrics.v_measure_score(y, pred)

for bandwidth in bandwidth_list:
    clst = MeanShift(bandwidth=bandwidth, bin_seeding=True)
    pred = clst.fit_predict(X)
    try:
        sc = metrics.v_measure_score(y, pred)
        if sc > best_sc:
            best_bandwidth = bandwidth
    except:
        pass
    
clst = MeanShift(bandwidth=best_bandwidth, bin_seeding=True)
pred = clst.fit_predict(X)
print(metrics.v_measure_score(y, pred))

plt.figure(figsize=(12,8))
plt.scatter(res[:,0], res[:,1], c=pred, s=10, cmap='viridis')
plt.title('TSNE - MeanShift - V-measure')
# Out:
# 0.039433701901049514
# Text(0.5, 1.0, 'TSNE - MeanShift - V-measure')

# %%
best_bandwidth = _bandwidth
bandwidth_list = np.arange(best_bandwidth-0.4, best_bandwidth+0.5, 0.1)

clst = MeanShift(bandwidth=best_bandwidth, bin_seeding=True)
pred = clst.fit_predict(X)    
best_sc = metrics.homogeneity_score(y, pred)

for bandwidth in bandwidth_list:
    clst = MeanShift(bandwidth=bandwidth, bin_seeding=True)
    pred = clst.fit_predict(X)
    try:
        sc = metrics.homogeneity_score(y, pred)
        if sc > best_sc:
            best_bandwidth = bandwidth
    except:
        pass
    
clst = MeanShift(bandwidth=best_bandwidth, bin_seeding=True)
pred = clst.fit_predict(X)
print(metrics.homogeneity_score(y, pred))

plt.figure(figsize=(12,8))
plt.scatter(res[:,0], res[:,1], c=pred, s=10, cmap='viridis')
plt.title('TSNE - MeanShift - Homogenity')
# Out:
# 0.08048226918718601
# Text(0.5, 1.0, 'TSNE - MeanShift - Homogenity')

# %%
best_bandwidth = _bandwidth
bandwidth_list = np.arange(best_bandwidth-0.4, best_bandwidth+0.5, 0.1)

clst = MeanShift(bandwidth=best_bandwidth, bin_seeding=True)
pred = clst.fit_predict(X)    
best_sc = metrics.homogeneity_score(y, pred)

for bandwidth in bandwidth_list:
    clst = MeanShift(bandwidth=bandwidth, bin_seeding=True)
    pred = clst.fit_predict(X)
    try:
        sc = metrics.homogeneity_score(y, pred)
        if sc > best_sc:
            best_bandwidth = bandwidth
    except:
        pass
    
clst = MeanShift(bandwidth=best_bandwidth, bin_seeding=True)
pred = clst.fit_predict(X)
print(metrics.completeness_score(y, pred))

plt.figure(figsize=(12,8))
plt.scatter(res[:,0], res[:,1], c=pred, s=10, cmap='viridis')
plt.title('TSNE - MeanShift - Completeness')
# Out:
# 0.026114473524126398
# Text(0.5, 1.0, 'TSNE - MeanShift - Completeness')
